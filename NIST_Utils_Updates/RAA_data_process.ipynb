# %%
import py_trees
import numpy as np
import behaviours as be
from py_trees.blackboard import Blackboard
import pandas as pd
from scipy import spatial
from sklearn.cluster import KMeans
from pandas import DataFrame
from annotator import annotator
import re

# %%
# read RAA 2017
##docu = '/Users/sileshu/Desktop/EMSData/RAA Data 2017.xlsx'
docu = './RAA Data 2017.xlsx'
df = pd.read_excel(docu)
narratives = df['Narrative']
interventions = df['Interventions']

# %%
# read labelled cases
docu = './AutoLabelCases (Haydon Additions).xlsx'
df = pd.read_excel(docu)
su = 0
protocol = {}
narratives = df['Narratives']
gt = []
pts = set()
for item in df['Corrected Protocol']:
    if not pd.isnull(item):
        gt.append(item)
        pts.add(item)
        
for item in df.iterrows():
    if item[1]['Corrected Protocol'] in protocol:
        protocol[item[1]['Corrected Protocol']] += 1
    else:
        protocol[item[1]['Corrected Protocol']] = 1

# %%
# build concept list
from search_term import search_term

# %%
pro_df = pd.read_excel('./ODEMSA_Protocols_weighted.xlsx')

# %%
ss = set()
inter = set()
for item in pro_df['Signs&Symptoms']:
    for i in item.split(';'):
        i = (i.strip().lower()[:-1],i.strip().lower()[-1])
        ss.add(i)
for item in pro_df['Interventions']:
    for i in item.split(';'):
        i = (i.strip().lower()[:-1],i.strip().lower()[-1])
        inter.add(i)
for item in pro_df['Possible signs&symptoms additions']:
    if pd.isnull(item):
        continue
    for i in item.split(';'):
        i = (i.strip().lower()[:-1],i.strip().lower()[-1])
        ss.add(i)

# %%
dft = pd.DataFrame()
dft['Required Concepts'] = list(ss)
dft.to_csv('RC.csv',index = False)

# %%
concept_mapping = {}
for i in ss:
    cuis = search_term(i[0], page_limit = 1, check = True)
    if len(cuis) == 0:
        print i
    else:
        concept_mapping[i] = cuis

# %%
for i in inter:
    cuis = search_term(i, page_limit = 1, check = True)
    if len(cuis) == 0:
        print i
    else:
        concept_mapping[i] = cuis
# Out:
# (u'cardiac monitor', u'3')
# (u'bag valve mask ventilation', u'3')
# (u'cardiac monitor', u'2')
# (u'suction the oropharynx', u'2')
# (u'nasopharyngeal airway', u'2')
# (u'bronchodilator', u'3')
# (u'encourage patient to relax', u'3')
# (u'endotracheal tube', u'3')
# (u'recovery position', u'2')
# (u'capnography', u'3')
# (u'physical restraint', u'2')
# (u'geodon', u'2')
# (u'metered dose inhaler', u'2')
# (u'suction the nasopharynx', u'1')
# (u'supine position', u'2')

# %%
dfs = []
for i in concept_mapping:
    df = DataFrame()
    cuis = [j[0] for j in concept_mapping[i]]
    names = [j[1] for j in concept_mapping[i]]
    concept = [i[0]] + [np.nan] * (len(cuis) - 1)
    df['Required Concept'] = concept
    df['CUI'] = cuis
    df['Preferred Name'] = names
    dfs.append(df)
concept_list = pd.concat(dfs)

# %%
inter
# Out:
# {(u'albuterol', u'3'),
#  (u'aspirin', u'3'),
#  (u'bag valve mask ventilation', u'3'),
#  (u'bronchodilator', u'3'),
#  (u'capnography', u'3'),
#  (u'cardiac monitor', u'2'),
#  (u'cardiac monitor', u'3'),
#  (u'cpap', u'3'),
#  (u'dexamethasone', u'3'),
#  (u'dextrose', u'3'),
#  (u'diazepam', u'1'),
#  (u'diazepam', u'2'),
#  (u'diazepam', u'3'),
#  (u'encourage patient to relax', u'3'),
#  (u'endotracheal tube', u'3'),
#  (u'epinephrine', u'2'),
#  (u'fentanyl', u'2'),
#  (u'geodon', u'2'),
#  (u'glucagon', u'2'),
#  (u'ipratropium', u'3'),
#  (u'magnesium sulfate', u'2'),
#  (u'metered dose inhaler', u'2'),
#  (u'midazolam', u'1'),
#  (u'midazolam', u'2'),
#  (u'midazolam', u'3'),
#  (u'morphine', u'2'),
#  (u'narcan', u'3'),
#  (u'nasopharyngeal airway', u'2'),
#  (u'nitroglycerin', u'2'),
#  (u'normal saline', u'2'),
#  (u'ondansetron', u'3'),
#  (u'oral glucose', u'3'),
#  (u'oxygen', u'1'),
#  (u'oxygen', u'2'),
#  (u'oxygen', u'3'),
#  (u'physical restraint', u'2'),
#  (u'recovery position', u'2'),
#  (u'suction the nasopharynx', u'1'),
#  (u'suction the oropharynx', u'2'),
#  (u'supine position', u'2'),
#  (u'transport', u'2'),
#  (u'transport', u'3')}

# %%
concept_list
# Out:
#    Required Concept       CUI  \
# 0         midazolam  C1351678
# 1               NaN  C1126025
# 2               NaN  C2920420
# 3               NaN  C3500195
# 4               NaN  C4048415
# 5               NaN  C0358428
# 6               NaN  C3857257
# 7               NaN  C0978647
# 8               NaN  C3502910
# 9               NaN  C3853826
# 10              NaN  C4048764
# 11              NaN  C4048417
# 12              NaN  C0978649
# 13              NaN  C2980829
# 14              NaN  C4048767
# 15              NaN  C4048414
# 16              NaN  C4048995
# 17              NaN  C3853824
# 18              NaN  C4271053
# 19              NaN  C4718880
# 20              NaN  C4719128
# 21              NaN  C4762530
# 0     paraphernalia  C0680329
# 1               NaN  C1337622
# 2               NaN  C1337623
# 3               NaN  C3841868
# 4               NaN  C3841869
# 5               NaN  C0776682
# 6               NaN  C0776984
# 7               NaN  C0776989
# ..              ...       ...
# 20              NaN  C3844448
# 21              NaN  C4015474
# 22              NaN  C4714945
# 23              NaN  C4715035
# 24              NaN  C4716602
# 0            oxygen  C0916139
# 1               NaN  C1334873
# 2               NaN  C1419605
# 3               NaN  C1585598
# 4               NaN  C1424062
# 5               NaN  C1431938
# 6               NaN  C1163085
# 7               NaN  C1164295
# 8               NaN  C0979217
# 9               NaN  C0979218
# 10              NaN  C1305553
# 11              NaN  C1432561
# 12              NaN  C1744120
# 13              NaN  C1744461
# 14              NaN  C2984411
# 15              NaN  C1585555
# 16              NaN  C0498450
# 17              NaN  C0498451
# 18              NaN  C1314597
# 19              NaN  C1314598
# 20              NaN  C2729173
# 21              NaN  C2729174
# 22              NaN  C0648757
# 23              NaN  C0979219
# 24              NaN  C0979220
#
#                                        Preferred Name
# 0                     Midazolam 2 MG/ML Oral Solution
# 1                                   Midazolam 2 MG/ML
# 2            2 ML Midazolam 1 MG/ML Prefilled Syringe
# 3                    2 ML Midazolam 1 MG/ML Cartridge
# 4                    2 ML Midazolam 1 MG/ML Injection
# 5               Midazolam 2 MG/ML Injectable Solution
# 6            2 ML Midazolam 5 MG/ML Prefilled Syringe
# 7               Midazolam 1 MG/ML Injectable Solution
# 8                 Midazolam 2 MG/ML Prefilled Syringe
# 9            1 ML Midazolam 5 MG/ML Prefilled Syringe
# 10                   2 ML Midazolam 5 MG/ML Injection
# 11                   5 ML Midazolam 1 MG/ML Injection
# 12              Midazolam 5 MG/ML Injectable Solution
# 13           1 ML Midazolam 2 MG/ML Prefilled Syringe
# 14                   1 ML Midazolam 5 MG/ML Injection
# 15  Midazolam Hydrochloride 1 MG/ML includes Injec...
# 16  Midazolam 1 MG/ML includes Prefilled Syringe &...
# 17  Midazolam 5 MG/ML includes Injectable Solution...
# 18  Midazolam Hydrochloride/Sodium Chloride 2 MG/1...
# 19  midazolam/ketamine HCl/ondansetron HCl 3 mg-25...
# 20  ketamine/midazolam/ondansetron 25 mg-3 mg-2 mg...
# 21  MIDAZOLAM 3 mg / KETAMINE HYDROCHLORIDE 25 mg ...
# 0                                  drug paraphernalia
# 1            INTRAPERITONEAL ADMIN.SETS-PARAPHERNALIA
# 2                         INFUSION SETS-PARAPHERNALIA
# 3                         Drug paraphernalia at scene
# 4           Alcohol containers/paraphernalia at scene
# 5   dialysis (peritoneal) kits MISCELL INTRAPERITO...
# 6   hypodermoclysis set-needles MISCELL INFUSION S...
# 7   intravenous administration set MISCELL INFUSIO...
# ..                                                ...
# 20          Cardiac dysrhythmia (irregular heartbeat)
# 21          Chronic atrial and intestinal dysrhythmia
# 22                  Knowledge: Dysrhythmia Management
# 23                       Self-Management: Dysrhythmia
# 24                  Signs and symptoms of dysrhythmia
# 0                N-Myc Downstream Regulated Protein 1
# 1                                          NDRG1 gene
# 2                                            RP1 gene
# 3                     Oxygen 100 % Gas for Inhalation
# 4                                          ROMO1 gene
# 5                                  RP1 protein, human
# 6                      Oxygen 21 % Gas for Inhalation
# 7                    Oxygen 99.2 % Gas for Inhalation
# 8                      Oxygen 99 % Gas for Inhalation
# 9                    Oxygen 99.5 % Gas for Inhalation
# 10                                       Oxygen 100 %
# 11          oxygen-evolving enhancer protein 1, plant
# 12                               Romo1 protein, mouse
# 13                               ROMO1 protein, human
# 14  Hypoxia and Oxygen Homeostasis Regulation of H...
# 15       Helium 80 % / Oxygen 20 % Gas for Inhalation
# 16  Portable oxygen contents, gaseous, 1 month's s...
# 17  Portable oxygen contents, liquid, 1 month's su...
# 18  Oxygen contents, gaseous, 1 unit equals 1 cubi...
# 19     Oxygen contents, liquid, 1 unit equals 1 pound
# 20  Stationary oxygen contents, gaseous, 1 month's...
# 21  Stationary oxygen contents, liquid, 1 month's ...
# 22                 alkanol monooxygenase (FMN-linked)
# 23                   Oxygen 99.6 % Gas for Inhalation
# 24                   Oxygen 99.9 % Gas for Inhalation
#
# [2518 rows x 3 columns]

# %%
narratives
# Out:
# 0      Dispatched for seizures    Aos to find 59 yof ...
# 1      A: Dispatched with RFD to club for employee wi...
# 2      A: 596 was dispatched to a P3 fall call. Upon ...
# 3      D: "diabetic problem"    A: Arrived to find a ...
# 4      D: Dispatched to the listed address for a psyc...
# 5      D- Unit 594 dispatched priority one for a brea...
# 6      D- Dispatched complaint: Breathing Difficulty ...
# 7      D:  Dispatched to the above address, a persona...
# 8      D- Dispatched complaint: Sick person       Oth...
# 9      D: Dispatched Priority 1 for hemorrhage/lacera...
# 10     Dispatch: Dispatched priority 1 for a breathin...
# 11     A: Dispatched for a female with vaginal bleedi...
# 12     Dispatch: Dispatched Priority 1 for the chest ...
# 13     [Dispatch]  M586 dispatched for the up/md    [...
# 14     D:  EMS dispatched for a sick person/interfaci...
# 15     D: 491 dispatched to sick person    A: Arrived...
# 16     Dispatch for a P.1 male unconscious but breath...
# 17     D- RAA responded immediately to 2000 RIVERSIDE...
# 18     D: Dispatched priority 1 for MVC.    A: AOS to...
# 19     »DISPATCH-DISPATCHED FOR PRIORITY 1 BREATHING ...
# 20     A: 573 was dispatched to a fainting call. Upon...
# 21     D/ Dispatched for chest pain.    A/ Arrived to...
# 22     [Dispatch]  M585 dispatched for the chest pain...
# 23     D- Dispatched priority one for a breathing pro...
# 24     »DISPATCH-DISPATCHED FOR PRIORITY 1 HEART PROB...
# 25     D: "unconscious/fainting"    A: Arrived to fin...
# 26     D:  EMS dispatched for an overdose.     A:  EM...
# 27     D- Dispatched to intersection for fall.    A- ...
# 28     d- dispatched for psychiatric/suicide    a- ar...
# 29     D: dispatched to the above listed address fora...
#                              ...
# 118    A: 592 was dispatched to a fall call. Upon arr...
# 119    D: Dispatched for a breathing problem     A: A...
# 120    Dispatched for a hemorrhage.    Arrived on sce...
# 121    d- dispatched for unconconscious    a- arrived...
# 122    D.  Dispatched with priority 3 to  Post office...
# 123    Dispatched For:Unconscious/Fainting    Number ...
# 124    D: Dispatched for a priority 1 seizure.    A: ...
# 125    Arrival:  pt found sitting upright, outside in...
# 126    D-DISPATCHED FOR PRIORITY UNCONCIOUS/FAINTING....
# 127    D: Dispatched Priority 1 downgraded to priorit...
# 128    D: Dispatched Priority 1 for a psych/suicide a...
# 129    D- Dispatched to sidewalk outside of residence...
# 130    Dispatch: Dispatched priority 1 for a traffic ...
# 131    D/ Dispatched for a sick person.    A/ Arrived...
# 132    d- dispatched for heart problem    a- arrived ...
# 133    D: Dispatched to the above listed address for ...
# 134    D: Medic 468 is dispatched to a residence for ...
# 135    D- Dispatched to residence with RPD for fall, ...
# 136    D - Medic 483 was dispatched for a diabetic pr...
# 137    D:  Unit 482 dispatched for medical call.  Upd...
# 138    A: Dispatched to the above address for a sick ...
# 139    A:  Dispatched to private residence for female...
# 140    A- Dispatched for chest pain. Arrived to find ...
# 141    Trauma name "TRPrice, M0449"    Called  to the...
# 142    (C) DISPATCHED FOR FEMALE IN NURSING HOME. THI...
# 143    D- Dispatched complaint: Hemorrhage       Othe...
# 144    D:  Dispatched to a call for an unconscious.  ...
# 145    a-dsp for unknown problem for 86yo female    c...
# 146    Dispatched For: Sick Person    Number of Units...
# 147    D: Dispatched to the above listed address for ...
# Name: Narratives, Length: 148, dtype: object

# %%
concept_list.to_csv('concept_list(s&s)_revised.csv',index = False)

# %%
# cluster protocol
pv = {}
for line in pro_df.iterrows():
    sv = []
    iv = []
    line_ss = [(i.strip().lower()[:-1],i.strip().lower()[-1]) for i in line[1]['Signs&Symptoms'].split(';')]
    line_inter = [(i.strip().lower()[:-1],i.strip().lower()[-1]) for i in line[1]['Interventions'].split(';')]
    if not pd.isnull(line[1]['Possible signs&symptoms additions']):
        line_ssr = [(i.strip().lower()[:-1],i.strip().lower()[-1]) for i in line[1]['Possible signs&symptoms additions'].split(';')]
    line_ss += line_ssr
    print line_ss
    name = line[1]['Protocol']
    for i in ss:
        res = 0.
        for j in line_ss:
            if i[0] == j[0]:
                res = 2.**int(j[1])
                break;
        sv.append(res)
    #for j in inter:
     #   iv.append(int(j in line_inter))
    pv[name] = sv
# Out:
# [(u'chest pain', u'3'), (u'pain region', u'2'), (u'pain radiation', u'3'), (u'pain severity', u'3'), (u'pale', u'3'), (u'diaphoresis', u'3'), (u'shortness of breath', u'2'), (u'nausea', u'2'), (u'vomiting', u'2'), (u'dizziness', u'1'), (u'chest pressure', u'3'), (u'pain chest wall', u'2'), (u'pain jaw', u'2'), (u'chest tightness', u'2')]
# [(u'abdominal pain', u'3'), (u'distension', u'3'), (u'rigidity', u'3'), (u'unequal femoral pulses', u'1'), (u'absent femoral pulses', u'1'), (u'diaphoresis', u'2'), (u'tenderness', u'2'), (u'nausea', u'3'), (u'vomiting', u'3'), (u'diarrhea', u'3'), (u'dysuria', u'3'), (u'constipation', u'3'), (u'vaginal bleeding', u'3'), (u'vaginal discharge', u'2'), (u'pregnancy', u'3'), (u'fever', u'3'), (u'headache', u'2'), (u'weakness', u'2'), (u'malaise', u'2'), (u'myalgias', u'2'), (u'cough', u'1'), (u'rash', u'1'), (u'rebound tenderness', u'3')]
# [(u'anxiety', u'2'), (u'agitation', u'3'), (u'confusion', u'2'), (u'hallucinations', u'3'), (u'delusional thoughts', u'2'), (u'bizarre behavior', u'2'), (u'combative', u'3'), (u'violent', u'3'), (u'suicidal thought', u'2'), (u'homicidal thoughts', u'3'), (u'abuse of substance', u'3'), (u'agitated delirium', u'3'), (u'hyperglycemia', u'3'), (u'hypoglycemia', u'3')]
# [(u'decreased mental status', u'2'), (u'sleepiness', u'2'), (u'incontinence', u'3'), (u'seizure', u'3'), (u'trauma', u'3'), (u'convulsions', u'3'), (u'tonic-clonic', u'3'), (u'post-ictal', u'3')]
# [(u'shortness of breath', u'3'), (u'tachypnea', u'3'), (u'bradypnea', u'3'), (u'use of accessory muscles', u'3'), (u'tripoding', u'3'), (u'wheezing', u'3'), (u'rhonchi', u'3'), (u'rales', u'3'), (u'fever', u'2'), (u'cough', u'3'), (u'tachycardia', u'2'), (u'hypoxemia', u'3')]
# [(u'decreased mental status', u'3'), (u'loss of consciousness', u'3'), (u'lightheadedness', u'2'), (u'dizziness', u'2'), (u'palpitations', u'2'), (u'tachycardia', u'2'), (u'bradycardia', u'2'), (u'dysrhythmia', u'2'), (u'hypertension', u'3'), (u'hypotension', u'3'), (u'fever', u'3'), (u'last known well', u'3'), (u'baseline neurological status', u'3')]
# [(u'anxiety', u'1'), (u'agitation', u'2'), (u'confusion', u'3'), (u'cool skin', u'3'), (u'clammy skin', u'3'), (u'diaphoresis', u'3'), (u'seizure', u'2'), (u'decreased visual acuity', u'2'), (u'blindness', u'2'), (u'tachycardia', u'2'), (u'hypertension', u'1'), (u'dizziness', u'2'), (u'headache', u'2'), (u'weakness', u'3'), (u'hypoglycemia', u'3')]
# [(u'mental status changes', u'3'), (u'hypotension', u'2'), (u'hypertension', u'2'), (u'hypothermia', u'3'), (u'hyperthermia', u'2'), (u'tachypnea', u'3'), (u'bradypnea', u'3'), (u'tachycardia', u'3'), (u'dysrhythmia', u'2'), (u'seizure', u'3'), (u'pin point pupils', u'3'), (u'substance abuse history', u'3'), (u'paraphernalia', u'3'), (u'abuse of substance', u'3')]

# %%
l = []
names = []
for i in pv:
    names.append(i)
    l.append(pv[i])
X = np.array(l)
kmeans = KMeans(n_clusters = 4, random_state=0).fit(X)

# %%
kmeans.labels_
# Out:
# array([2, 0, 0, 1, 3, 0, 3, 3], dtype=int32)

# %%
names
# Out:
# [u'Medical - Abdominal Pain',
#  u'Medical - Altered Mental Status',
#  u'Medical - Seizure',
#  u'Medical - Respiratory Distress/Asthma/COPD/Croup/Reactive Airway',
#  u'General - Behavioral/Patient Restraint',
#  u'Medical - Overdose/Poisoning - Opioid',
#  u'Medical - Diabetic - Hypoglycemia',
#  u'Medical - Chest Pain - Cardiac Suspected']

# %%
group = dict()
x = kmeans.labels_
for i,name in enumerate(names):
    if x[i] in group:
        group[x[i]].append(name)
    else:
        group[x[i]] = [name]

# %%
#Somehow make sure that the two metamap servers are on and running
#TP#!/bin/bash /public_mm/bin/skrmedpostctl start &
#TP#!/bin/bash /public_mm/bin/wsdserverctl start &

# %%
# extract concept and calculate similarity
from ranking_func import rank
def pre_tick_handler(behaviour_tree):
    blackboard = Blackboard()
    blackboard.tick_num += 1
texts = ['Upper lobes bilaterally and quiet lower lobes bilaterally initial Vital Signs BP 162 over 94 pulse 120 for respirations 36 skin is warm and moistpulse oximetry 92% on 15 LPM by non-rebreather ECG']
results = []
scores = []
ConceptRes = []
for item in narratives:
    blackboard = Blackboard()
    blackboard.text = [item]
    root = py_trees.composites.Sequence("Root_1")
    IG = be.InformationGathering()
    TC = be.TextCollection()
    V = be.Vectorize()
    root.add_children([TC,IG,V])
    behaviour_tree = py_trees.trees.BehaviourTree(root)
    behaviour_tree.add_pre_tick_handler(pre_tick_handler)
    behaviour_tree.setup(15)
    print('Item: ', i)
    behaviour_tree.tick_tock(
            sleep_ms=50,
            number_of_iterations=1,
            pre_tick_handler=None,
       post_tick_handler=None
        )
    scores.append(blackboard.ranking)
    ConceptRes.append(blackboard.ConcLog)
    results.append(rank(blackboard.ranking))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-66df699338bd> in <module>()
#      18     behaviour_tree = py_trees.trees.BehaviourTree(root)
#      19     behaviour_tree.add_pre_tick_handler(pre_tick_handler)
# ---> 20     behaviour_tree.setup(15)
#      21     print('Item: ', i)
#      22     behaviour_tree.tick_tock(
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/py_trees/trees.pyc in setup(self, timeout)
#     202             :obj:`bool`: suceess or failure of the operation
#     203         """
# --> 204         return self.root.setup(timeout)
#     205
#     206     def tick(self, pre_tick_handler=None, post_tick_handler=None):
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/py_trees/composites.pyc in setup(self, timeout)
#      82         result = True
#      83         for child in self.children:
# ---> 84             new_result = child.setup(timeout)
#      85             if new_result is None:
#      86                 # replace with py_trees exception!
#
# /home/lidolla/Documents/DSA/NIST/behaviours.pyc in setup(self, unused_timeout)
#      64         for item in vcl:
#      65             self.sce.SpecificInit(item)
# ---> 66         # Vital Signs Concept Extractor
#      67         self.vce = CE.ConceptExtractor(self.vlist)
#      68         #self.vce.StatusInit()
#
# AttributeError: 'ConceptExtractor' object has no attribute 'Status'

# %%
Inters = []
for item in interventions:
    inter = item.strip('{}').split('}{')
    inter = [i.split(':')[-1].strip().lower() for i in inter]
    Inters.append(inter)
interset = set()
for i in Inters:
    for j in i:
        interset.add(j)

# %%
protocol2inter = {
    'Medical - Chest Pain - Cardiac Suspected':['oxygen','cardiac monitor','12-lead ecg',\
                               'aspirin','midazolam (versed)','diazepam (valium)',\
                                'nitroglycerine','fentanyl','hospital contact','iv','normal saline'],
    'Medical - Abdominal Pain':['oxygen','cardiac monitor','12-lead ecg',\
                                'iv','normal saline','ondansetron (zofran)','hospital contact'],
    'General - Behavioral/Patient Restraint':['oxygen','midazolam (versed)','diazepam (valium)',\
                                              'hospital contact'],
    'General - Pain Control':['oxygen','cardiac monitor','12-lead ecg',\
                              'acetaminophen (tylenol)','iv','normal saline','fentanyl'],
    'Medical - Seizure':['nasopharyngeal airway insertio','oxygen',\
                        'iv','normal saline','midazolam (versed)','diazepam (valium)',\
                        'cardiac monitor','12-lead ecg','hospital contact'],
    'Medical - Respiratory Distress/Asthma/COPD/Croup/Reactive Airway':['oxygen','capnography (1) first reading',\
                                                                        'capnography (2) second reading','capnography (3) final reading',\
                                                                       'assist ventilation (bvm)','endotracheal','duoneb','albuterol',
                                                                       'ipratropium (atrovent)','dexamethasone (decadron)','cpap',\
                                                                       'magnesium sulfate'],
    'Medical - Altered Mental Status':['oxygen','cardiac monitor','12-lead ecg','iv','normal saline',\
                                       'hospital contact'],
    'Medical - Diabetic - Hypoglycemia':['oxygen','cardiac monitor','12-lead ecg','iv','normal saline',\
                                       'hospital contact','dextrose 10%','dextrose 25%','dextrose 5% in 0.45% ns',\
                                        'dextrose 50%','oral glucose'],
    'Medical - Overdose/Poisoning - Opioid':['oxygen','cardiac monitor','12-lead ecg','iv','normal saline',\
                                       'hospital contact','naloxone (narcan)']
}

# %%
predict_inters = []
overlap_rate = []
for idx,item in enumerate(results):
    res = []
    for j in item[:3]:
        res += protocol2inter[j]
    res = set(res)
    predict_inters.append(res)
    ct = 0
    for i in Inters[idx]:
        if i in res:
            ct += 1
    overlap_rate.append(float(ct)/float(len(Inters[idx])))

# %%
dfo = pd.DataFrame()
dfo['Narrative'] = narratives
dfo['Intervention'] = Inters
dfo['Score'] = scores
dfo['Ranking'] = [i[:3] for i in results]
dfo['Predict Intervention'] = predict_inters
dfo['Overlap Rate'] = overlap_rate
dfo.to_excel('OverlapEval_RAA2017.xlsx',index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-3395c4611fae> in <module>()
#       1 dfo = pd.DataFrame()
#       2 dfo['Narrative'] = narratives
# ----> 3 dfo['Intervention'] = Inters
#       4 dfo['Score'] = scores
#       5 dfo['Ranking'] = [i[:3] for i in results]
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/internals/construction.pyc in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
sum(overlap_rate)/len(overlap_rate)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-25-0ea54b119e0c> in <module>()
# ----> 1 sum(overlap_rate)/len(overlap_rate)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
dfr = DataFrame()
dfr['Narratives'] = narratives
dfr['Concepts'] = ['\n'.join(['(' + ','.join(i.strip('()').split(',')[:3]) + ')' for i in item]) for item in ConceptRes]
dfr.to_excel('ConceptExtracEval_ODEMSA.xlsx',index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a0b7b645a79a> in <module>()
#       1 dfr = DataFrame()
#       2 dfr['Narratives'] = narratives
# ----> 3 dfr['Concepts'] = ['\n'.join(['(' + ','.join(i.strip('()').split(',')[:3]) + ')' for i in item]) for item in ConceptRes]
#       4 dfr.to_excel('ConceptExtracEval_ODEMSA.xlsx',index = False)
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/internals/construction.pyc in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
for i in range(len(narratives)):
    if not isinstance(narratives[i], basestring):
        print i

# %%
gt = df['Corrected Protocol']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-41edd5eebf80> in <module>()
# ----> 1 gt = df['Corrected Protocol']
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Corrected Protocol'

# %%
# rank and calculate ndcg
pool = set(['Medical - Abdominal Pain',
            'General - Pain Control',
            'Medical - Altered Mental Status',
            'Medical - Seizure',
            'Medical - Respiratory Distress/Asthma/COPD/Croup/Reactive Airway',
            'General - Behavioral/Patient Restraint',
            'Medical - Overdose/Poisoning - Opioid',
            'Medical - Diabetic - Hypoglycemia',
            'Medical - Chest Pain - Cardiac Suspected'])
def rank(scores):
    srt = sorted(scores,key=lambda x: x[1], reverse=True)
    return [i[0] for i in srt]
bina = []
ranks = []
ndcgs = []

def nDCG(rank,gt,group,num):
    from numpy import log2
    for i in group:
        if gt in group[i]:
            break
    ct = len(group[i]) - 1
    idcg = 2.
    idx = 1
    num -= 1
    while (ct&num):
        idcg += 1/log2(idx+2)
        idx += 1
        ct -= 1
        num -= 1
    
    dcg = 0.
    for idx,item in enumerate(rank):
        if item == gt:
            dcg += 2/log2(idx+2)
        elif item in group[i]:
            dcg += 1/log2(idx+2)
        else:
            continue
    return dcg/idcg

for i,s in enumerate(scores):
    res = rank(s)
    
    if gt[i] in pool:
        bina.append(gt[i] in res[:3])
        ranks.append(res)
        ndcgs.append(nDCG(res[:3],gt[i],group,3))

# %%
float(sum(bina))/len(bina)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-30-3ed7d1cd1ec5> in <module>()
# ----> 1 float(sum(bina))/len(bina)
#
# ZeroDivisionError: float division by zero

# %%
float(sum(ndcgs)/len(ndcgs))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-31-a55c9ff4b6e9> in <module>()
# ----> 1 float(sum(ndcgs)/len(ndcgs))
#
# ZeroDivisionError: integer division or modulo by zero

# %%
t = [i[1]['Narratives'] for i in df.iterrows() if i[1]['Corrected Protocol'] in pool]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-5b01771369f6> in <module>()
# ----> 1 t = [i[1]['Narratives'] for i in df.iterrows() if i[1]['Corrected Protocol'] in pool]
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /home/lidolla/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# KeyError: 'Corrected Protocol'

# %%
len(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3941e0efbbc0> in <module>()
# ----> 1 len(t)
#
# NameError: name 't' is not defined

# %%
len(ranks)
# Out:
# 0

# %%
# store results
dfr = DataFrame()
dfr['Narratives'] = t
dfr['Scores'] = [s for i,s in enumerate(scores) if gt[i] in pool]
dfr['Rank'] = ranks
dfr['GroundTruth'] = [g for g in gt if g in pool]
dfr['Correctness'] = bina
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b61d7a5f55c8> in <module>()
#       1 # store results
#       2 dfr = DataFrame()
# ----> 3 dfr['Narratives'] = t
#       4 dfr['Scores'] = [s for i,s in enumerate(scores) if gt[i] in pool]
#       5 dfr['Rank'] = ranks
#
# NameError: name 't' is not defined

# %%
dfr.to_excel('VecMethEval_ODEMSA_weighted&revised.xlsx',index = False)
